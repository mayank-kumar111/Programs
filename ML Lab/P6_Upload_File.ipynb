# %%
# importing data from google drive in google colab
from google.colab import drive
drive.mount("/content/drive") # Mounting Google Drive

import pandas as pd
dataset = pd.read_csv('LINK_TO_YOUR_FILE')
print(dataset)

# %%
# importing data from local drive in google colab
from google.colab import files
uploaded = files.upload()
