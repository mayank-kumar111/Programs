# %%
# NumPy Library
import numpy as np

a=np.array([1,2,3])
print(a)

# %%
arr = np.array([1, 2, 3, 4, 5])

print(arr)

print(type(arr))

# %%
import numpy as np

arr = np.array([1, 2, 3, 4])

print(arr[0])
