# %%
# Command Line arguments
from sys import argv
print(f"Type of argv is : {type(argv)}")
print(f"First argument is : {argv[0]}")
# Out:
# Type of argv is : <class 'list'>
# First argument is : C:\Users\Mayan\AppData\Roaming\Python\Python314\site-packages\ipykernel_launcher.py

# %%
lst_number = [10, 20, 30, 40, 50]
# list iteration
sum = 0
for num in lst_number:
    sum += num
print(f"Sum of list number is : {sum}")
# Out:
# Sum of list number is : 150

# %%
# Command Line arguments
from sys import argv
cmd_argument = argv[1:]
sum =0
for number in cmd_argument:
    sum += int(number)
print(f"Sum of command line argument is : {sum}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 6
#       4 sum =0
#       5 for number in cmd_argument:
# ----> 6     sum += int(number)
#       7 print(f"Sum of command line argument is : {sum}")
#
# ValueError: invalid literal for int() with base 10: '--f=c:\\Users\\Mayan\\AppData\\Roaming\\jupyter\\runtime\\kernel-v352310473a2b48d5b452705d5a758fe033cf260c2.json'

# %%
# P2_module_demo.py
def multiply(a, b):
    prod = a * b
    return prod
class Test:
    pass
print("P2_module_demo.py is executed")
# Out:
# P2_module_demo.py is executed

# %%
# Take Multiple inputs
x,y = [int(x) for x in input("Enter Two numbers separated by a comma: ").split(",")]
print(f"X = {x}, Y = {y}")

'''list_1 = input("Enter multiple values separated by a comma: ").split(",")
print(f"Type of list_1 is : {type(list_1)}")
x,y = list_1

x=int(x)
y=int(y)
print(f"X = {x}, Y = {y}")'''
# Out:
# X = 5, Y = 6
# 'list_1 = input("Enter multiple values separated by a comma: ").split(",")\nprint(f"Type of list_1 is : {type(list_1)}")\nx,y = list_1\n\nx=int(x)\ny=int(y)\nprint(f"X = {x}, Y = {y}")'
